# %%
#dataframe

# %%
import pandas as pd
print('done')
# Out:
# done

# %%
#1d_data = series
#2d_data = Muiltiple series row and column :-DF

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
# dataframe

# %%
# dict

# %%
data = {'Names':['Mohan','Sahil','Deepak','Ayush'],
        'salary':[23456,8765,5678,8786],
        'Address':['Noida','Delhi','Gr noida','Gurgaon']}

# %%
pd.DataFrame(data)
# Out:
#     Names  salary   Address
# 0   Mohan   23456     Noida
# 1   Sahil    8765     Delhi
# 2  Deepak    5678  Gr noida
# 3   Ayush    8786   Gurgaon

# %%
#list of list
data = [[1,2,3,4,5,9],
        [2,2,2,2,6,8],
        [3,3,3,3,9,0]]
pd.DataFrame(data,columns=['Col_'+str(i+1) for i in range(len(data[0]))])
# Out:
#    Col_1  Col_2  Col_3  Col_4  Col_5  Col_6
# 0      1      2      3      4      5      9
# 1      2      2      2      2      6      8
# 2      3      3      3      3      9      0

# %%
import numpy as np

# %%
data = np.full((5,5),5)
pd.DataFrame(data,columns=['Col_'+str(i+1) for i in range(len(data[0]))])
# Out:
#    Col_1  Col_2  Col_3  Col_4  Col_5
# 0      5      5      5      5      5
# 1      5      5      5      5      5
# 2      5      5      5      5      5
# 3      5      5      5      5      5
# 4      5      5      5      5      5

# %%
data = '''Name, Age, Salary
Ayush,12,87654,
karan,23,98765'''

# %%
data.splitlines()
# Out:
# ['Name, Age, Salary', 'Ayush,12,87654,', 'karan,23,98765']

# %%
d=pd.read_excel(r"C:\Users\ASUS\OneDrive\Desktop\New Microsoft Excel Worksheet.xlsx")

# %%
d
# Out:
#    id    name  salary  dept
# 0   2   Ayush     667    it
# 1   6      om    2435  aiml
# 2   0  sanjay    3557    cs
# 3   7   karan    7654   iot
# 4   8   shera    9889    ds

# %%
#path = '''https://github.com/ayushh1013/Power-bi_dashboard_project/blob/main/super%20sale.pbix'''
#Wpd.read_csv(path)

# %%
#pd.ExcelFile(r"").sheet_names

# %%
pd.read_excel;(r"C:\Users\ASUS\OneDrive\Desktop\EXCEL FORMULA.ods",sheet_names ='')
# Out:
# 'C:\\Users\\ASUS\\OneDrive\\Desktop\\EXCEL FORMULA.ods'

# %%
#execute

# %%
for i in range(10000):
    exec (f'a_{i} = 100')

# %%
a_1
# Out:
# 100

# %%
a_11
# Out:
# 100

# %%
all_sheets = pd.ExcelFile(r"C:\Users\ASUS\OneDrive\Desktop\New Microsoft Excel Worksheet.xlsx").sheet_names

# %%
for i , value in enumerate(all_sheets):
    exec(f'''table_{i+1} = pd.read_excel(r"C:\\Users\\ASUS\\OneDrive\\Desktop\\New Microsoft Excel Worksheet.xlsx",sheet_name = value)''')

# %%
table_1
# Out:
#    id    name  salary  dept
# 0  67   Ayush     667    it
# 1   6      om    2435  aiml
# 2   0  sanjay    3557    cs
# 3   7   karan    7654   iot
# 4   8   shera    9889    ds

# %%
table_2
# Out:
#    id    name  salary  dept
# 0  89   Ayush     667    it
# 1   6      om    2435  aiml
# 2   0  sanjay    3557    cs
# 3   7   karan    7654   iot
# 4   8   shera    9889    ds

# %%
table_3
# Out:
#    id    name  salary  dept
# 0  99   Ayush     667    it
# 1   6      om    2435  aiml
# 2   0  sanjay    3557    cs
# 3   7   karan    7654   iot
# 4   8   shera    9889    ds
