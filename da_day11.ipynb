# %%
import pandas as pd

# %%
date_series = pd.date_range(start = '01/01/2024',end='31/12/2024')

# %%
type(date_series)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
import numpy as np

# %%
y = np.random.randint(1,1000,366)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(date_series[:20],y[:20])
plt.xticks(rotation = 90)
plt.show()

# %%
data_series = pd.date_range(start = '01/01/2024',end='31/03/2024',period = 3)
data_series
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-15', '2024-03-31'], dtype='datetime64[ns]', freq=None)

# %%
data_series = pd.date_range(start = '01/01/2024',end='31/03/2024',freq = 's')
data_series
# Out:
# DatetimeIndex(['2024-01-01 00:00:00', '2024-01-01 00:00:01',
#                '2024-01-01 00:00:02', '2024-01-01 00:00:03',
#                '2024-01-01 00:00:04', '2024-01-01 00:00:05',
#                '2024-01-01 00:00:06', '2024-01-01 00:00:07',
#                '2024-01-01 00:00:08', '2024-01-01 00:00:09',
#                ...
#                '2024-03-30 23:59:51', '2024-03-30 23:59:52',
#                '2024-03-30 23:59:53', '2024-03-30 23:59:54',
#                '2024-03-30 23:59:55', '2024-03-30 23:59:56',
#                '2024-03-30 23:59:57', '2024-03-30 23:59:58',
#                '2024-03-30 23:59:59', '2024-03-31 00:00:00'],
#               dtype='datetime64[ns]', length=7776001, freq='s')

# %%
data_series = pd.date_range(start = '2025-09-30 23:26:49.865594',end='2025-09-30 23:26:49.865594',freq  = 'ns')
data_series
# Out:
# DatetimeIndex(['2025-09-30 23:26:49.865594'], dtype='datetime64[ns]', freq='ns')

# %%
from datetime import datetime,timedelta

# %%
print(datetime.now())
# Out:
# 2025-09-30 23:26:49.865594

# %%
print(datetime.now() + timedelta(2))
# Out:
# 2025-10-02 23:30:04.888889

# %%
#to_csv

# %%
d = {'col1':[1,2],'col2':[3,4]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df.to_csv('Ayush.csv',index=False)
print('done')
# Out:
# done

# %%
path = r"C:\Users\ASUS\OneDrive\Desktop\pandas\Ayush.csv"
df.to_csv(path,index = 0)
print('done')
# Out:
# done

# %%
df.to_dict(orient = 'list')
# Out:
# {'col1': [1, 2], 'col2': [3, 4]}

# %%
df.to_dict(orient = 'records')
# Out:
# [{'col1': 1, 'col2': 3}, {'col1': 2, 'col2': 4}]

# %%
df.to_excel('filename.xlsx',index=False)

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %%
adani = pd.read_csv(r"C:\Users\ASUS\Downloads\adani.csv")

# %%
adani.to_html('adani.html')

# %%
adani.to_json('adani.json')

# %%
df.to_markdown()
# Out:
# '|    |   col1 |   col2 |\n|---:|-------:|-------:|\n|  0 |      1 |      3 |\n|  1 |      2 |      4 |'

# %%
adani.to_xml('adani.xml')

# %%
#df.to_sql()

# %%
#file transfer
df.to_pickle('df.pkl')

# %%
impo
with open('df.pkl','rb') as f:
    loaded_df = pickle.load(f)
